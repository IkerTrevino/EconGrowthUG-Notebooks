# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib widget

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Exercise 1:</b> Write a function that computes the level of output generated by a constant returns to scale Cobb-Douglas production function, i.e., such that it computes $A\cdot K^\alpha \cdot L^{1-\alpha}$.
# </div>

# %%
def CobbDouglas(K=1, L=1, A=1, alpha=0.3):
    '''
    This function computes the level of output of a Cobb-Douglas production function.
    Given values of K, L, A, and alpha it returns $A\cdot K^\alpha \cdot L^{1-\alpha}$.
    Parameters:
    -----------
    K: float, integer or any other number, default=1
    L: float, integer or any other number, default=1
    A: float, integer or any other number, default=1
    alpha: float between (0,1), default=0.3
    
    Returns:
    --------
    out = A * K**alpha * L**(1-alpha)
    
    Example:
    >>> out = CobbDouglas(4, 9, 2, 1/2)
    >>> out
        12
    '''
    return A*K**alpha*L**(1-alpha)

# %%
CobbDouglas(4, 9, 2, 1/2)
# Out:
# 12.0

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Exercise 2:</b> Use the function you created and plot the production function as a function of $K$ for given values of $A$ and $L$. <b>Hint:</b> Use the <code>np.linspace(0, 5, 100)</code> function to create an array of values of $K$ with 100 point between 0 and 5.
# </div>

# %%
k=np.linspace(0, 5, 100)
k
# Out:
# array([0.        , 0.05050505, 0.1010101 , 0.15151515, 0.2020202 ,
#        0.25252525, 0.3030303 , 0.35353535, 0.4040404 , 0.45454545,
#        0.50505051, 0.55555556, 0.60606061, 0.65656566, 0.70707071,
#        0.75757576, 0.80808081, 0.85858586, 0.90909091, 0.95959596,
#        1.01010101, 1.06060606, 1.11111111, 1.16161616, 1.21212121,
#        1.26262626, 1.31313131, 1.36363636, 1.41414141, 1.46464646,
#        1.51515152, 1.56565657, 1.61616162, 1.66666667, 1.71717172,
#        1.76767677, 1.81818182, 1.86868687, 1.91919192, 1.96969697,
#        2.02020202, 2.07070707, 2.12121212, 2.17171717, 2.22222222,
#        2.27272727, 2.32323232, 2.37373737, 2.42424242, 2.47474747,
#        2.52525253, 2.57575758, 2.62626263, 2.67676768, 2.72727273,
#        2.77777778, 2.82828283, 2.87878788, 2.92929293, 2.97979798,
#        3.03030303, 3.08080808, 3.13131313, 3.18181818, 3.23232323,
#        3.28282828, 3.33333333, 3.38383838, 3.43434343, 3.48484848,
# ...

# %%
CobbDouglas(K=k,L=9,A=2,alpha=1/2)
# Out:
# array([ 0.        ,  1.34839972,  1.90692518,  2.33549683,  2.69679945,
#         3.01511345,  3.3028913 ,  3.56753034,  3.81385036,  4.04519917,
#         4.26401433,  4.47213595,  4.67099366,  4.86172435,  5.04524979,
#         5.22232968,  5.3935989 ,  5.55959449,  5.72077554,  5.87753814,
#         6.03022689,  6.17914381,  6.32455532,  6.46669791,  6.60578259,
#         6.74199862,  6.87551651,  7.0064905 ,  7.13506068,  7.26135474,
#         7.38548946,  7.50757194,  7.62770071,  7.74596669,  7.86245393,
#         7.97724035,  8.09039835,  8.20199532,  8.31209415,  8.42075358,
#         8.52802865,  8.63397096,  8.73862898,  8.8420483 ,  8.94427191,
#         9.04534034,  9.14529188,  9.24416278,  9.34198733,  9.43879807,
#         9.53462589,  9.62950013,  9.7234487 ,  9.81649817,  9.90867389,
#        10.        , 10.09049958, 10.18019468, 10.26910636, 10.35725481,
#        10.44465936, 10.53133851, 10.61731005, 10.70259102, 10.7871978 ,
# ...

# %%
fig, ax = plt.subplots(figsize = (8,5))
x=k
y= CobbDouglas(K=k,L=9,A=2,alpha=1/2)
figure1= plt.plot(x,y, c ='b', marker = 'D', linestyle ='-', label =r'$y=x^2$')
ax.set_xlabel(r'$k$', fontsize = 18)
ax.set_ylabel(r'$GDP$', fontsize = 18)
ax.set_title(r'CobbDouglas', fontsize = 18)
plt.savefig('/Users/ikertrevino/Desktop/Economic Growth/Solutions.png')
plt.savefig('/Users/ikertrevino/Desktop/Economic Growth/Solutions.pdf')
plt.savefig('/Users/ikertrevino/Desktop/Economic Growth/Solutions.jpg')
plt.show(figure1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Exercise 3:</b> Show with a plot the effect of increasing $A$ from 1 to 2, 4, or 5.
# </div>

# %%
fig, ax = plt.subplots(figsize = (8,5))
x=k
y2 = CobbDouglas(K=k,L=9,A=1,alpha=1/2)
y3 = CobbDouglas(K=k,L=9,A=2,alpha=1/2)
y4 = CobbDouglas(K=k,L=9,A=4,alpha=1/2)
y5 = CobbDouglas(K=k,L=9,A=5,alpha=1/2)
figure2= plt.plot(x,y2, c ='b', marker = 'D', linestyle = '-', label =r'$A=1$')
figure2= plt.plot(x,y3, c ='r', marker = 'D', linestyle = '-', label =r'$A=2$')
figure2= plt.plot(x,y4, c ='y', marker = 'D', linestyle = '-', label =r'$A=3$')
figure2= plt.plot(x,y5, c ='g', marker = 'D', linestyle = '-', label =r'$A=4$')
ax.set_xlabel(r'$k$', fontsize = 18)
ax.set_ylabel(r'$GDP$', fontsize = 18)
ax.set_title(r'CobbDouglas with Tech', fontsize = 18)
plt.savefig('/Users/ikertrevino/Desktop/Economic Growth/Solutions.png')
plt.savefig('/Users/ikertrevino/Desktop/Economic Growth/Solutions.pdf')
plt.savefig('/Users/ikertrevino/Desktop/Economic Growth/Solutions.jpg')
plt.show(figure2)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Exercise 4:</b> Show with a plot the effect of increasing $L$ from 1 to 2, 4, 5.
# </div>

# %%
fig, ax = plt.subplots(figsize = (8,5))
x=k
y2 = CobbDouglas(K=k,L=1,A=2,alpha=1/2)
y3 = CobbDouglas(K=k,L=2,A=2,alpha=1/2)
y4 = CobbDouglas(K=k,L=4,A=2,alpha=1/2)
y5 = CobbDouglas(K=k,L=5,A=2,alpha=1/2)
figure3= plt.plot(x,y2, c ='b', marker = 'D', linestyle = '-', label =r'$A=1$')
figure3= plt.plot(x,y3, c ='r', marker = 'D', linestyle = '-', label =r'$A=2$')
figure3= plt.plot(x,y4, c ='y', marker = 'D', linestyle = '-', label =r'$A=3$')
figure3= plt.plot(x,y5, c ='g', marker = 'D', linestyle = '-', label =r'$A=4$')
ax.set_xlabel(r'$k$', fontsize = 18)
ax.set_ylabel(r'$GDP$', fontsize = 18)
ax.set_title(r'CobbDouglas with change in L', fontsize = 18)
plt.savefig('/Users/ikertrevino/Desktop/Economic Growth/Solutions.png')
plt.savefig('/Users/ikertrevino/Desktop/Economic Growth/Solutions.pdf')
plt.savefig('/Users/ikertrevino/Desktop/Economic Growth/Solutions.jpg')
plt.show(figure3)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Exercise 5:</b> Save the previous plots into <b>png, jpeg, and pdf</b> files.
# </div>

# %%
See Code Above
